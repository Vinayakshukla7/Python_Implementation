# %%
from requests_html import HTMLSession
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
unique_no=[]

# %%
def get_soup(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    return soup

def page_number(base_url):
    soup=get_soup(base_url)
    no=soup.find('div',{'class':'_2MImiq'})
    pg_no=no.find('span').text.split(' ')[3]
    return pg_no

def model_no(url):
    sess = HTMLSession() 
    info = sess.get(url)
    soup=BeautifulSoup(info.text,'html.parser')
    items = info.html.find('div[data-id]')
    for item in items:
        if item.attrs['data-id'] != '':
            unique_no.append(item.attrs['data-id'])

# %%
search_by='samsung smartphone'
initial_page=1
ini_url=f'https://www.flipkart.com/search?q={search_by}&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={initial_page}'

total_page=page_number(ini_url)
for current in range(1,int(total_page)+1):
    url_new=f'https://www.flipkart.com/search?q={search_by}&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={current}'
    model_no(url_new)

# %%
unique_no
# Out:
# ['MOBFV5PWG5MGD4CF',
#  'MOBGFG79BVGDHGWV',
#  'MOBFV5PWEX7WJS7R',
#  'MOBFRZZH4HHGU6YT',
#  'MOBGFG79BPTJWHKS',
#  'MOBFRZZHZGSRRWUZ',
#  'MOBGFG79FUDPXZXQ',
#  'MOBGFG8GCPEGKGF4',
#  'MOBGFG79FKRYJ8D4',
#  'MOBGFG79ZZFRGZ7U',
#  'MOBFV5PWUHRY2MZZ',
#  'MOBFSFMJJBTXPTRR',
#  'MOBGFG79GQGAYVNV',
#  'MOBFSF86NH2HVZAW',
#  'MOBFVV4HRYZSYBA6',
#  'MOBFPNPSZYJXQZCM',
#  'MOBFRZZHH4WHKZCW',
#  'MOBGFG8H4A32HTKJ',
#  'MOBGFZUNGH22RJZT',
#  'MOBFRZZHYYH7KBGZ',
#  'MOBGY73CKG9HXZZB',
#  'MOBGY73CXJBUBTF7',
#  'MOBG2VPGK8RCMGQY',
#  'MOBFRZZHV9KS2XGR',
#  'MOBFRZZHV9KS2XGR',
#  'MOBFZWSUMTPWSGQH',
#  'MOBFRZZHFMBJC4A6',
#  'MOBFSF867ET7DDMZ',
#  'MOBGYCCGCCAAXUVV',
#  'MOBGFG794YPQ9RAE',
#  'MOBFRZZHWPX3YG2J',
#  'MOBGY73CF6SYPZ3S',
#  'MOBFPNPS6GTGZHE4',
#  'MOBGY73C7Y6HUTCR',
#  'MOBFZG4CNAGAV4HW',
#  'MOBGFG79NYAKZFH5',
#  'MOBFVWCTZYMFQH3J',
#  'MOBGFG79NWFGVZRY',
#  'MOBFS72HDJXVHAYP',
#  'MOBGY73CNRHW6TMZ',
#  'MOBFS72HZ9A2FNZP',
#  'MOBFV25HNQP3VNGP',
#  'MOBFWCFDEHTZVQMZ',
#  'MOBFZWSUHXGQMUPH',
#  'MOBFZWSTSZGFGGTR',
#  'MOBGY73CF3UYCUDU',
#  'MOBFZJ7KYB8U8KPY',
#  'MOBFZWSUZZ2Y7YYG',
#  'MOBFZWSUZZ2Y7YYG',
#  'MOBFRZZHEMXTAE6H',
#  'MOBFTQDBQRGVNGAZ',
#  'MOBGYCCGG2E47PQF',
#  'MOBFUYQTCWZVMGEK',
#  'MOBFUZYBUZWNKB6G',
#  'MOBFUAEBY34F3GYV',
#  'MOBFX3JN2QA3RYZE',
#  'MOBFUYQTFBAYCFKG',
#  'MOBGYCCGWY8EYMNW',
#  'MOBGFZUHYABADANE',
#  'MOBGFG79GYGKEHCA',
#  'MOBGYRZG9ASEDZT7',
#  'MOBGYCCGAP9FG7FV',
#  'MOBFZG4C8VAYP4SH',
#  'MOBFZ4AJCTQTDJEB',
#  'MOBGYCCGGPXZHSWB',
#  'MOBFZ4AJRFZTYZHJ',
#  'MOBFVVEJRYZ73YSF',
#  'MOBFX77NDJXMDZZY',
#  'MOBFRZZHMHQVNDFA',
#  'MOBGYCCGPEPHFHWM',
#  'MOBFTW76ZWAJGFWA',
#  'MOBFV5PWXJRV9WZZ',
#  'MOBGY73CDWHBJKE7',
#  'MOBFTW767YN8JXUQ',
#  'MOBFSFMJHFVHCQ2X',
#  'MOBFXYA9ZMJG9VTY',
#  'MOBFRZZHRFVXDUZZ',
#  'MOBFWVRYQ8DRGQEB',
#  'MOBFRZZHHUZTTYCZ',
#  'MOBFWCFDZWGKHXNG',
#  'MOBFZ3TMAZGVZF5D',
#  'MOBFZ3TM9RVNZACT',
#  'MOBFSF85ZMVH3ZMG',
#  'MOBFWCFDGDW84W6G',
#  'MOBFWVNZNW8D8BJK',
#  'MOBFV5PWGEVNPWS2',
#  'MOBFKKGRHVDRVUY6',
#  'MOBG2VGGFYZU99GU',
#  'MOBESWZM2Z8GBCHF',
#  'MOBFSFMJZVFVNDAG',
#  'MOBFKKGRPQDS98WH',
#  'MOBFV5PWHRYTYYJF',
#  'MOBFPNPSZWQ7YKGH',
#  'MOBFZ4AJ2FZGJKCF',
#  'MOBFZXZ25TPA68VH',
#  'MOBGFG79NWTZMMHY',
#  'MOBFKZ8W9JQGMTZY',
#  'MOBFZWSUEMTZDC7U',
#  'MOBFSFMJ7F9YHGGC',
#  'MOBGFG8GWBRPHMKT',
#  'MOBFZG4CZGKXZBQ2',
#  'MOBFRZZHZTY3GHCY',
#  'MOBFYZ8Y9VJNACEM',
#  'MOBFE4CSRHGF4ETQ',
#  'MOBFZ3TMAHBPXYNZ',
#  'MOBFWAVTQNMETGGG',
#  'MOBFYZAHMWSYDE9H',
#  'MOBFZ3TMYQ8WTHJE',
#  'MOBGFZUGASJGRSDK',
#  'MOBFU5WYPMCGAZ6J',
#  'MOBGFG79MASHH2ZH',
#  'MOBFWAVTM5YD3JNE',
#  'MOBFUYMQUW5EKE7R',
#  'MOBFSF86ZVPMUZD3',
#  'MOBFWAVTMGYNUDHW',
#  'MOBFZ3TMHZ2WATFY',
#  'MOBFKKGRJCHHRJS5',
#  'MOBF9BT83EFMX6P7',
#  'MOBFGREWXSH4CMD8',
#  'MOBFUAGVPHANZXNZ',
#  'MOBF2VWVGZCF39YY',
#  'MOBFZ4AJPCURHRQZ',
#  'MOBFZ4AJTYFSXMCV',
#  'MOBFH6HYT5Z5ZPER',
#  'MOBFDNHAYZYR5VXE',
#  'MOBFZ3TMT2RHYG5K',
#  'MOBFUKHDNAZGZUAZ',
#  'MOBFZ3TMSMXZATX3',
#  'MOBFZ3TMYAWQAJDP',
#  'MOBFAJ724YYKAMXR',
#  'MOBFNZGE5GNBCGVZ',
#  'MOBFGHZ2CHC2SYSA',
#  'MOBF7HXTNGF3MJFD',
#  'MOBFBM2FAGEB8F3X',
#  'MOBF7F65HBUYF2TY',
#  'MOBFEHSMHMYUMWYK',
#  'MOBFE7VRHSYJEGSQ',
#  'MOBFJPAQNZTBSZFZ',
#  'MOBFH6HRX3WG97RQ',
#  'MOBFE4CSF3G2TTUV',
#  'MOBFDNHARGTYX5YG',
#  'MOBFSFMJKQPBWJFB',
#  'MOBFERTHUAJJ4MWH',
#  'MOBFU5WYMX5Y8YCY',
#  'MOBES429GPANCACZ',
#  'MOBF7F65G8YHXQQZ',
#  'MOBFU5WYVAAGDCGW',
#  'MOBFFYFQ4CDPXGUP',
#  'MOBFSFMJFZDCCQZT',
#  'MOBF8WMQ2UY95V2V',
#  'MOBFU5WY7UFG4KD9',
#  'MOBFERW7XXSYQYH3',
#  'MOBFZXZ22CWZ2JZB',
#  'MOBFKZ78EV34ZQRY',
#  'MOBFG4SHFNYFDQFW',
#  'MOBF8WZ6BQXK26YG',
#  'MOBFG83KGXJSBEWY',
#  'MOBFWXFVHFKDCYUG',
#  'MOBF7F65RHKJNYPH',
#  'MOBFUAEBBSAWG6HG',
#  'MOBFUAEBGXVGX5US',
#  'MOBFUAGV5QW3MMZW',
#  'MOBFUAEBGZKRFGHX',
#  'MOBFKKGRNXCA4FTW',
#  'MOBF7HXTUS5GWYKC',
#  'MOBF7F65MUBJGCSH',
#  'MOBEU7JZEYSWGHSG',
#  'MOBFE4CSBDN9XETN',
#  'MOBF5BKHVHFGWYHB',
#  'MOBF47DRKFBAYVFX',
#  'MOBFE4CSDXZHFGZ6',
#  'MOBFE4CSUQHGWE9V',
#  'MOBFJPAQNZTBSZFZ',
#  'MOBF6GZTM8BDQZGG',
#  'MOBF8BFPQ3BZJJR7',
#  'MOBFE4CWZMKTZGFH',
#  'MOBFFAG4C5CZF4VN',
#  'MOBFJPAQUNZRTVUX',
#  'MOBEUGGE2DGK6EJH',
#  'MOBFNZGEBGYMQCYP',
#  'MOBF8DJJUCJYZQVP',
#  'MOBEMNHF97T55KYZ',
#  'MOBF7HXTC2J7YZ2E',
#  'MOBF9BT8MHEZDRHZ',
#  'MOBFFAG46KYERGRF',
#  'MOBFEN5UBRFSFEMC',
#  'MOBF5BKHAK33A75F',
#  'MOBFHCRGJQJUY7QG',
#  'MOBF94BXS83YGWBX',
#  'MOBEG4XWG33HXYT7',
#  'MOBF8BFPKTJ7EY7K',
#  'MOBFHCRGDFASPZRA',
#  'MOBEBFQE4WFKV2TF',
#  'MOBF5BKHX5GKHFW6',
#  'MOBFEN5UDNHGSGVX',
#  'MOBEYM9W5YZQPZZ2',
#  'MOBF5PZHAVHBUVNX',
#  'MOBE5Z49V4ZHZPRH',
#  'MOBF8BFPQHHN4VV7',
#  'MOBFDNHAEBRVM7NZ',
#  'MOBF5BKHYMMYEWN8',
#  'MOBF5PZHU3AWSMYS',
#  'MOBF47DRZSZJDQHR',
#  'MOBEVYZYWYEQVJK7',
#  'MOBF7F65CAFSVHWB',
#  'MOBEMNHGABKEKCJR',
#  'MOBF649RJHMTCNRV',
#  'MOBFYTD7ZMWAWRFW',
#  'MOBF5BKH5A2WFENZ',
#  'MOBF94C4VASZ42HU',
#  'MOBEU7JZE4GAQM24',
#  'MOBECCA5SMRSKCNY',
#  'MOBF47DRCVEP9HMF',
#  'MOBFDNMZC29CBUPF',
#  'MOBF6GZT38FAD4X5',
#  'MOBF649RZ6HT9ZQU',
#  'MOBF7F6523G2JHYZ',
#  'MOBF5BKHSYMVYE3A',
#  'MOBFFAG4YPASHGEB',
#  'MOBFE4CSJX4KJN5R',
#  'MOBF649RGYKVV88N',
#  'MOBFEN5USXHVJMMQ',
#  'MOBESKMTQM7N9BXH',
#  'MOBF5PZHGU4MWFEV',
#  'MOBF47DRA4RG4R2R',
#  'MOBFNMRDC27KFZBR',
#  'MOBF47DRPJA8DAQY',
#  'MOBF94BXFS3WSHMG',
#  'MOBF6GZTRMVDUVSJ',
#  'MOBF94BX8HBYHDFC',
#  'MOBEG4XWMBDGZVEX',
#  'MOBEMNHGUTDKTGYW',
#  'MOBFHCRGZZHFRDDA',
#  'MOBEVYZYZUZFUHSJ',
#  'MOBESKMTUZB6KHUP',
#  'MOBFZWSUZGKGHMHD',
#  'MOBGY73CSBKNXA5W',
#  'MOBFZG4DZCRQUEDC',
#  'MOBGYRZGNXF5WTJH',
#  'MOBGYRZGHZZDAY5D',
#  'MOBFUG5ZAXZNGGZN',
#  'MOBG3KGVPW53GUV4',
#  'MOBG3KGVVVVZ6YHF',
#  'MOBFSHFB6MXGJNH6',
#  'MOBFYZ673HRWNNCD',
#  'MOBGF8GP5UHJNP5G',
#  'MOBGF8GPFCD25ZU5',
#  'MOBFE69APFAP9HNA',
#  'MOBFZ4AJH5SGQUQC',
#  'MOBFS72H6Z6SPUZC',
#  'MOBFQ29NXHVM9DVN',
#  'MOBGF8GPYZMCHBCV',
#  'MOBFE5A9Y37Y9BYX',
#  'MOBFKKGRAC5NQH97',
#  'MOBEQBFSFJAYZAZA',
#  'MOBFZ8N6YQAMU3Q5',
#  'MOBFSHFBFGNWPSXF',
#  'MOBFPDVHRHKHDNZE',
#  'MOBFDYVFZ6JYE8YG',
#  'MOBFKKGRGA3E2PYP',
#  'MOBFQ29N2WWGFRKG',
#  'MOBFJPAQ53GGFVZD',
#  'MOBFZ4AJAZFZPZHA',
#  'MOBFJPAQWGQPZPVE',
#  'MOBFFAG4J2MYDTMT',
#  'MOBFPDVHAJMVXUYZ',
#  'MOBFEAP5YPYMYCNZ',
#  'MOBGF8GP8S2KB3Q6',
#  'MOBFQ29NNU5T5BCB',
#  'MOBFE45MWRFNYHN8',
#  'MOBEBFQEAFUN9F5E',
#  'MOBFJPAQFKS6QPHT',
#  'MOBENHRN5NRTFCNE',
#  'MOBFZXZ2GAFXSZUX',
#  'MOBFYZYPVYFYNEZZ',
#  'MOBFFHC7Z2KGSGH3',
#  'MOBFE5AFBDFXVHDX',
#  'MOBFZ4AJJSWKTTAU',
#  'MOBGYRZGTFSUDXSY',
#  'MOBFZ8HTYDB5RDZF',
#  'MOBFZ4AJVJAXCJRB',
#  'MOBFZ7HFZQXTJYAY',
#  'MOBFZ3TM2T968PFW',
#  'MOBGF8GPZFGZW2GD',
#  'MOBGF8GPTCGRAXZH',
#  'MOBFKZ8NRZ6XZGFE',
#  'MOBFZ3TMHG3G3DZZ',
#  'MOBFJFWVWDC7B3A2',
#  'MOBFK4REVNMAUGCJ',
#  'MOBDUZSYRMG7R3U9',
#  'MOBFE4CSQ4MDCBWF',
#  'MOBFPDVHFE8VVD9R',
#  'MOBEBCTXQTP4MKBH',
#  'MOBGF8GPMMHPTFNM',
#  'MOBFK9AVSTDSDMW6',
#  'MOBGF8GPRFYJ2UDF',
#  'MOBFFHC76PNFBXVG',
#  'MOBFK4REDUB3FUDR',
#  'MOBFD98GJGFRTYMC',
#  'MOBGF8GPQMN4YGPN',
#  'MOBDZRDTTFCVNBD5',
#  'MOBFZ3TM5FT52G79',
#  'MOBFZ4AJSDNY5TEH',
#  'MOBFJPAQTXRY8WNZ',
#  'MOBEYFC44EUDZ9TX',
#  'MOBEY7ZMZMXT7NM2',
#  'MOBFSHFBGSVYBJQ3',
#  'MOBE5HPCSZKH5JGP',
#  'MOBFK4REFQTCSVNA',
#  'MOBFFAG4SQHGZDHH',
#  'MOBGF8GPZTYZDHH6',
#  'MOBFFAG4EGT6HYZZ',
#  'MOBFKKGRTHKTGUSS',
#  'MOBFKKGRNTSSPSSZ',
#  'MOBFKKGRKBTNANRH',
#  'MOBEYAW2YZNKXETE',
#  'MOBEYAW2RHYDBA2G',
#  'MOBDZRDTQRSAHE3N',
#  'MOBFAJ729HH2G8FY',
#  'MOBEG4XWHJDWMQDF',
#  'MOBE9YNTWJZAU2KQ',
#  'MOBEFZCAM98UGRCJ',
#  'MOBEFZCAGR2YGZYB',
#  'MOBEFZCA4NGBHDM6',
#  'MOBEQ4S4PKGV8YTR',
#  'MOBEGYZXXD3WYJMJ',
#  'MOBFKKGRRKCB9WEH',
#  'MOBDZRDTKGJXRGZH',
#  'MOBF2SHXCZ4A7MQS',
#  'MOBEBF3XJUFFWRRZ',
#  'MOBFAJ72ZGPA4FFT',
#  'MOBFK4REENZZFHHK',
#  'MOBFYZYPBW7BYS89',
#  'MOBFUG5ZAXZNGGZN',
#  'MOBF3QNQ2H3CZZHU',
#  'MOBFAJ72EG8KFZEM',
#  'MOBFAJ72EG8KFZEM',
#  'MOBFZ7H5ESHYZJFJ',
#  'MOBDZRDT6YGX9HVZ',
#  'MOBEQBGBCNBUG7HJ',
#  'MOBF6FZ4QMNCA48H',
#  'MOBFU897FS2HKWFE',
#  'MOBFFHC7GQZCF8YM',
#  'MOBFWS6DVDFRXWDV',
#  'MOBDZQ2EZM3TAFBX',
#  'MOBEQBGBKYSNHDGT',
#  'MOBFZ4AJ3ZHTERBH',
#  'MOBEHEUHZ7MHQZFX',
#  'MOBERQS4DGYMUY7Z',
#  'MOBFK4REY6GGXSAY',
#  'MOBEBF3XFPGHJYUR',
#  'MOBEFZRGZUGFCGQD',
#  'MOBF3HVDWPGCHXZB',
#  'MOBFZ8HTSDNVQGPG',
#  'MOBE93GW9XJXNXES',
#  'MOBFK4RES2FYEHGP',
#  'MOBF9BT8VHGRAXFZ',
#  'MOBGF8GPCKFJSZG4',
#  'MOBFKKGRXCY5ENB6',
#  'MOBEG76Y6RZEJHTM',
#  'MOBFGHZ2CC2PW5TJ',
#  'MOBEBGYKYYHHRP8T',
#  'MOBE93GWZDT9YMGD',
#  'MOBFK4REX35HWCVT',
#  'MOBDZQ2EGPHQPJCH',
#  'MOBE93GWSMGZHFSK',
#  'MOBF94C4Z64FPUNQ',
#  'MOBFZ4AJZ6KGUPQR',
#  'MOBF9BT8GMB9HPRR',
#  'MOBFNZGE7KUYX5YK',
#  'MOBFJFWVVMDNSFCF',
#  'MOBEBFQE8UEKCYSD',
#  'MOBF3HVDCJG3SUJF',
#  'MOBFKKGRN7DNW9Q8',
#  'MOBE3UN6CSXCP28A',
#  'MOBF94C4Q2GNQBRH',
#  'MOBGF8GPBTCRPWWQ',
#  'MOBECKHZZPEHJDHZ',
#  'MOBFE4CS3FDSGEZR',
#  'MOBEGFZPFQ6GGHCV',
#  'MOBFEZS5MRSVHXHE',
#  'MOBE93GWSA63AU7V',
#  'MOBE93GWRFFGPGRC',
#  'MOBFJFWVQM52KMCG',
#  'MOBE56HEMBMHGY6H',
#  'MOBEBBDVYYHPU88Y',
#  'MOBF6FZ4R9QNKKY9',
#  'MOBEDFF8T4THCVQE',
#  'MOBEBBGRZND2E6SU',
#  'MOBFZ8HTN4F7HHSV',
#  'MOBEG4XWDK4WBGNU',
#  'MOBFK4REY2CUGAG7',
#  'MOBF6K4HTWPQUFMZ',
#  'MOBGF8GPV9FWUSNK',
#  'MOBDHKWZ7AE7UMGH',
#  'MOBEMJRFZXZBESQW',
#  'MOBECCA5Y5HBYR3Q',
#  'MOBFWAVTKRH6GFQG',
#  'MOBEG4XWFTBRMMBY',
#  'MOBEG4XWJG7F9A6Z',
#  'MOBFYZ67JNPRDY3T',
#  'MOBFZ3TMU3GTUHRK',
#  'MOBFZ3TMDZJZQANF',
#  'MOBEB893DPPYKHBM',
#  'MOBDZM5BREYUEEUF',
#  'MOBFZ3TMZFGUFBYX',
#  'MOBDUUDTADHVQZXG',
#  'MOBEB893PU2JFTFF',
#  'MOBDUZSYZCA7HDYW',
#  'MOBF2VWVGM32SD5P',
#  'MOBEB893YGQMF5QM',
#  'MOBFK4REEVWGFXES',
#  'MOBFZXZ2D7UTXHEH',
#  'MOBFWAVTCMDRNRFB',
#  'MOBF3QNQKF2YTGVU',
#  'MOBFJFWV34VTRDGQ',
#  'MOBEKGN98Z54BRWC',
#  'MOBFY25VRHBTF7YF',
#  'MOBF7F65N6GDHFCB',
#  'MOBF7HXTQPVA5GGZ',
#  'MOBFBCC549GUDSXS',
#  'MOBF3QNQC8FTVZZV',
#  'MOBEU8N96CTFYAWG',
#  'MOBDHRHZYUHK7GFN',
#  'MOBF7HXTDMZVA365',
#  'MOBES42JH3XAHUZZ',
#  'MOBEYAW2V25HZNAV',
#  'MOBFZ3TMCEHYWGNG',
#  'MOBE3XZ7ZBZ9ADRR',
#  'MOBF5Z4UZAPYBN46',
#  'MOBE3XZ7ZEGHTKNB',
#  'MOBF2VWVHDAZRQGH',
#  'MOBE3XZ7ZEGHTKNB',
#  'MOBF2VWVHDAZRQGH',
#  'MOBF3QNQU6V5SKRW',
#  'MOBE3UN6MWTHGZ53',
#  'MOBF2VWVBGCT5QQN',
#  'MOBFZXZ2VCCBNYHF',
#  'MOBFAJ72E55Z4FYH',
#  'MOBE5Z49WRV8M5VV',
#  'MOBE3XZ7ZKRJZWSG',
#  'MOBE3UN6TRUFPKTD',
#  'MOBE5Z49XD5ZWTJM',
#  'MOBDWA2DXGZHMSDF',
#  'MOBDUUDTUFXXUQBD',
#  'MOBES42JBFYDAYHE',
#  'MOBDVP8DZJXQYJSD',
#  'MOBF2VWVCCGVAJP7',
#  'MOBF3QNQXXHY2H9T',
#  'MOBDTRBZSVFGZVXC',
#  'MOBEQCJ7DM5NRTJC',
#  'MOBEYAW2HCYCQJRZ',
#  'MOBEAZ67CYGB3VC3',
#  'MOBEBFKHGJBYAWR9',
#  'MOBF2VWVGHF5FERH',
#  'MOBFBCC5ZDHKKH9M',
#  'MOBGF8GPMXGBARHS',
#  'MOBEMZHFNAEVAJK9',
#  'MOBE3UN6NZHPXEBZ',
#  'MOBF3ZRVC9VZXKVG',
#  'MOBEW8QBJQYYDKKR',
#  'MOBENKYGHFUHT6BH',
#  'MOBE9YNTHPHFRM62',
#  'MOBEMZHFBUKN29WT',
#  'MOBDWA2DHSPRJPD9',
#  'MOBFFFZ4UD7JRXDS',
#  'MOBE3XZ7WPGUWWKN',
#  'MOBES42JDGBPPTYV',
#  'MOBF7F86UGKQXQCE',
#  'MOBE5Z49YEWGHNAR',
#  'MOBF2VWVGHQXYSPW',
#  'MOBDK7U9KZZKWZ9T',
#  'MOBE5Z49YWRM4DVU',
#  'MOBEHEUH4HYRT7TZ',
#  'MOBFH8Q8HCY53TTR',
#  'MOBFDNHABB3V23FY',
#  'MOBFH8Q3XRFQTNDF',
#  'MOBEMZGZDGGVJEUE',
#  'MOBDYGDVNG45AEFG',
#  'MOBF7F86HGYUV8EZ',
#  'MOBE9YNTUZFBSYH5',
#  'MOBE93GWZDQ4NJ9Z',
#  'MOBESWZMSJZXCD8T',
#  'MOBFJFWV8DBNZPYT',
#  'MOBFJFWVDFXQJDFE',
#  'MOBFX2HBBH8BSPTE',
#  'MOBEYAW2BT7MFW9Y',
#  'MOBEGFZPWJHYT7NX',
#  'MOBEKGN97XKM2EE4',
#  'MOBEH4ZNN4NZEUAH',
#  'MOBEG76YFGANT9GW',
#  'MOBE8ASZNYK83VTH',
#  'MOBEGYPDKJVFUJNC',
#  'MOBEGFKDPTG4D2HY',
#  'MOBF9BT8HT5ADRZZ',
#  'MOBF5J6BJXGBYBFH',
#  'MOBFDNHAXFKU9MHA',
#  'MOBFY4NYWWE9ZFFN',
#  'MOBFDNHAVZQ7SDDQ',
#  'MOBFDNHAFPNTTYBD',
#  'MOBEWGJSRUZURF9D',
#  'MOBE4U8NGG6MXJWC',
#  'MOBFDNHATGJSGGWS',
#  'MOBE536H33FEN2MN',
#  'MOBFJFWVNZRY3KNB',
#  'MOBFJFWVAFPGGPV8',
#  'MOBE4U8NHABCD37V',
#  'MOBDTGFZ8BRJVGS3',
#  'MOBDZSDJAPQXGAWN',
#  'MOBFZXZ2RNFPRFGV',
#  'MOBE3XZ7HGBSZNM8',
#  'MOBEAFYYXMDREHZX',
#  'MOBENZYMSEFQEXRZ',
#  'MOBESKMTZTAUHHQV',
#  'MOBE57KX7UYT9QEX',
#  'MOBE3YHYVD8WSJDX',
#  'MOBEQBFPZ8FYGYUB',
#  'MOBEGFZPMZTYFHAD',
#  'MOBFGHZ2Y8GHZVEW',
#  'MOBEYAW2PMH7UTDZ',
#  'MOBDQ22YUJ8ZFXKW',
#  'MOBF6KZQ2XYTRGGV',
#  'MOBEGFZPKXDMDBJ2',
#  'MOBDHKWZX5SMWMPX',
#  'MOBDT55VZHY3DCWP',
#  'MOBDY3H2W7WMTVCX',
#  'MOBE3YHYT95F2SYU',
#  'MOBDPPJZKSKKXAXE',
#  'MOBFZXZ2N3QFFFNZ',
#  'MOBEBF3X7R79VZGZ',
#  'MOBF3QNQDABVYTPR',
#  'MOBE4FJDFAVAGWDF',
#  'MOBFWS622SPGF23H',
#  'MOBE3XZ7C3NYWNHZ',
#  'MOBEAGMSX3P2DCSQ',
#  'MOBDH48MF4ZCAFWP',
#  'MOBECKHZV7PA6GDX',
#  'MOBE4ZVGZKHNVQJK',
#  'MOBDH48M3M3SXFPR',
#  'MOBE3UN6EURWTZCA',
#  'MOBF7HXT4JNEEPV3',
#  'MOBEYAW2FRFCVE45',
#  'MOBE4U8NZFQ32QFP',
#  'MOBE5Z49FVDCW5EU',
#  'MOBE57KXHCS97BRZ',
#  'MOBEGFZPCHJHAZVU',
#  'MOBE9SCD2ZY96AUF',
#  'MOBEYAW2RFHQG83F',
#  'MOBECKGY8F9RGSYJ',
#  'MOBEYAW2YQANCQKA',
#  'MOBFDS58BHGQPGHA',
#  'MOBEAFBEP8VBBDJP',
#  'MOBDMMPY6KN2YBA2',
#  'MOBDNZCCEJKWDKXU',
#  'MOBE3UN6WVPRFCZM',
#  'MOBE5Z49QHGXVHDN',
#  'MOBDRRYRWADX9DNK',
#  'MOBE3UN6KGCGK2EP',
#  'MOBDKESQYYHXFJJ7',
#  'MOBE5Z49HE46PNVF',
#  'MOBE5Z49FGGMSNGV',
#  'MOBE536HNEEGXHCW',
#  'MOBDUZSYQHSFYYU3',
#  'MOBDZUHGMJZTSEHC',
#  'MOBE37ANUWY4P6GG',
#  'MOBEFBYMJEPQGMPY',
#  'MOBDP6W62AJNWKZJ',
#  'MOBFDNHAZFKR9Q7Y',
#  'MOBEYAW2ZYEVJ5TA',
#  'MOBE3UN6NYKGPZPM',
#  'MOBDQZPY6EUNAPXJ',
#  'MOBFDNHAQWWD9TDZ',
#  'MOBEAFBEBZNE7CUF',
#  'MOBDQZPYAZSDKBWH',
#  'MOBEAY7MQXZYHCQZ',
#  'MOBDVYHZYSHJSECN',
#  'MOBDVYHZYSHJSECN',
#  'MOBDZB3Q8WJNKVHG',
#  'MOBE5Z49W4UHYHYZ',
#  'MOBDN4ZDZ564QBND',
#  'MOBEPYPTYGYGF8ZH',
#  'MOBDMMPYRYSGT7WA',
#  'MOBFYYBBZYQEUDQP',
#  'MOBEAHEHNUGJNWY4']

# %%
print(len(unique_no))
# Out:
# 584
